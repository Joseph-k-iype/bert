# %%
import pandas as pd
from transformers import BertTokenizer, BertModel
import torch
from sklearn.metrics.pairwise import cosine_similarity

# %%
dataset = pd.read_csv('/content/creative_mock_financial_dataset.csv')

# %%
model_name = 'bert-base-uncased'
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertModel.from_pretrained(model_name)

# %%
from torch.utils.data import DataLoader
import numpy as np

# Function to vectorize a batch of texts
def bert_vectorize_batch(texts, batch_size=32):
    vectorized_texts = []
    dataloader = DataLoader(texts, batch_size=batch_size, shuffle=False)

    for batch in dataloader:
        inputs = tokenizer(batch, return_tensors='pt', padding=True, truncation=True, max_length=512)
        outputs = model(**inputs)
        batch_vectors = outputs.last_hidden_state.mean(dim=1).squeeze().detach().numpy()
        vectorized_texts.extend(batch_vectors)

    return np.array(vectorized_texts)

# Applying the function to the dataset in batches
batch_size = 32  # You can adjust the batch size based on your system's capabilities
business_term_vectors = bert_vectorize_batch(dataset['Business Term Description'].tolist(), batch_size)
preferred_term_vectors = bert_vectorize_batch(dataset['Preferred Term Description'].tolist(), batch_size)

# Adding the vectors to the dataset
dataset['Business Term Vector'] = list(business_term_vectors)
dataset['Preferred Term Vector'] = list(preferred_term_vectors)

# %%
def calculate_similarity(vec1, vec2):
    return cosine_similarity(vec1.reshape(1, -1), vec2.reshape(1, -1))[0][0]

# %%
dataset['Similarity Score'] = dataset.apply(lambda x: calculate_similarity(x['Business Term Vector'], x['Preferred Term Vector']), axis=1)

# %%
# threshold = 0.8
# outliers = dataset[dataset['Similarity Score'] < threshold]

# # Displaying potential outliers
# outliers
# Calculate the 25th percentile of the similarity scores as the threshold
threshold = dataset['Similarity Score'].quantile(0.25)

# Identifying outliers
outliers = dataset[dataset['Similarity Score'] < threshold]
outliers
# Out:
#    Business Term ID         Business Term Name  \
# 0         BTID_0001     High-Value Customer ID
# 1         BTID_0002  Budget Allocation Summary
# 6         BTID_0007      Vendor Payment System
# 17        BTID_0018  Budget Allocation Summary
# 18        BTID_0019  Equity Investment Tracker
# 19        BTID_0020  Equity Investment Tracker
# 20        BTID_0021  Budget Allocation Summary
# 25        BTID_0026     High-Value Customer ID
# 29        BTID_0030      Vendor Payment System
# 37        BTID_0038      Vendor Payment System
# 40        BTID_0041     High-Value Customer ID
# 43        BTID_0044     High-Value Customer ID
# 46        BTID_0047  Budget Allocation Summary
# 48        BTID_0049     High-Value Customer ID
# 53        BTID_0054     Interest Rate Forecast
# 54        BTID_0055         Debt Recovery Plan
# 57        BTID_0058     Interest Rate Forecast
# 60        BTID_0061         Debt Recovery Plan
# 63        BTID_0064     High-Value Customer ID
# 64        BTID_0065      Vendor Payment System
# 73        BTID_0074     High-Value Customer ID
# 79        BTID_0080  Budget Allocation Summary
# 86        BTID_0087  Budget Allocation Summary
# 95        BTID_0096     Interest Rate Forecast
#
#                    Business Term Description Preferred Business Term  \
# 0      Description of high-value customer id         Market Analysis
# 1   Description of budget allocation summary   Investment Strategies
# 6       Description of vendor payment system         Market Analysis
# 17  Description of budget allocation summary         Market Analysis
# 18  Description of equity investment tracker      Regulatory Affairs
# 19  Description of equity investment tracker      Regulatory Affairs
# 20  Description of budget allocation summary        Client Relations
# 25     Description of high-value customer id         Market Analysis
# 29      Description of vendor payment system         Market Analysis
# 37      Description of vendor payment system      Regulatory Affairs
# 40     Description of high-value customer id         Market Analysis
# 43     Description of high-value customer id   Investment Strategies
# 46  Description of budget allocation summary        Client Relations
# 48     Description of high-value customer id         Market Analysis
# 53     Description of interest rate forecast        Client Relations
# 54         Description of debt recovery plan        Client Relations
# 57     Description of interest rate forecast        Client Relations
# 60         Description of debt recovery plan        Client Relations
# 63     Description of high-value customer id   Investment Strategies
# 64      Description of vendor payment system      Regulatory Affairs
# 73     Description of high-value customer id         Market Analysis
# 79  Description of budget allocation summary        Client Relations
# 86  Description of budget allocation summary        Client Relations
# 95     Description of interest rate forecast        Client Relations
#
#               Preferred Term Description  \
# 0         Description of market analysis
# 1   Description of investment strategies
# 6         Description of market analysis
# 17        Description of market analysis
# 18     Description of regulatory affairs
# 19     Description of regulatory affairs
# 20       Description of client relations
# 25        Description of market analysis
# 29        Description of market analysis
# 37     Description of regulatory affairs
# 40        Description of market analysis
# 43  Description of investment strategies
# 46       Description of client relations
# 48        Description of market analysis
# 53       Description of client relations
# 54       Description of client relations
# 57       Description of client relations
# 60       Description of client relations
# 63  Description of investment strategies
# 64     Description of regulatory affairs
# 73        Description of market analysis
# 79       Description of client relations
# 86       Description of client relations
# 95       Description of client relations
#
#                                  Business Term Vector  \
# 0   [0.06376215, -0.17287911, -0.059349936, 0.0746...
# 1   [-0.15764685, -0.21334161, -0.147244, 0.044736...
# 6   [-0.11818923, -0.21713245, 0.093217045, 0.0894...
# 17  [-0.15764685, -0.21334161, -0.147244, 0.044736...
# 18  [0.05248444, -0.31040645, 0.11933964, -0.11970...
# 19  [0.05248444, -0.31040645, 0.11933964, -0.11970...
# 20  [-0.15764685, -0.21334161, -0.147244, 0.044736...
# 25  [0.06376215, -0.17287911, -0.059349936, 0.0746...
# 29  [-0.11818923, -0.21713245, 0.093217045, 0.0894...
# 37  [-0.11818923, -0.21713245, 0.093217045, 0.0894...
# 40  [0.06376215, -0.17287911, -0.059349936, 0.0746...
# 43  [0.06376215, -0.17287911, -0.059349936, 0.0746...
# 46  [-0.15764685, -0.21334161, -0.147244, 0.044736...
# 48  [0.06376215, -0.17287911, -0.059349936, 0.0746...
# 53  [-0.06322492, -0.3076882, -0.06561124, 0.00512...
# 54  [0.025930157, -0.1818845, 0.014293975, 0.03968...
# 57  [-0.06322492, -0.3076882, -0.06561124, 0.00512...
# 60  [0.025930157, -0.1818845, 0.014293975, 0.03968...
# 63  [0.06376215, -0.17287911, -0.059349936, 0.0746...
# 64  [-0.11818923, -0.21713245, 0.093217045, 0.0894...
# 73  [0.06376215, -0.17287911, -0.059349936, 0.0746...
# 79  [-0.15764685, -0.21334161, -0.147244, 0.044736...
# 86  [-0.15764685, -0.21334161, -0.147244, 0.044736...
# 95  [-0.06322492, -0.3076882, -0.06561124, 0.00512...
#
#                                 Preferred Term Vector  Similarity Score
# 0   [-0.19709682, -0.27392277, -0.5515117, -0.1885...          0.715076
# 1   [-0.0749434, 0.0049636485, -0.38076004, -0.087...          0.719111
# 6   [-0.19709682, -0.27392277, -0.5515117, -0.1885...          0.750580
# 17  [-0.19709682, -0.27392277, -0.5515117, -0.1885...          0.708618
# 18  [0.3134871, 0.057133112, -0.47340408, 0.099212...          0.719977
# 19  [0.3134871, 0.057133112, -0.47340408, 0.099212...          0.719977
# 20  [-0.23902147, 0.1319948, -0.29529908, -0.08826...          0.712706
# 25  [-0.19709682, -0.27392277, -0.5515117, -0.1885...          0.715076
# 29  [-0.19709682, -0.27392277, -0.5515117, -0.1885...          0.750580
# 37  [0.3134871, 0.057133112, -0.47340408, 0.099212...          0.701750
# 40  [-0.19709682, -0.27392277, -0.5515117, -0.1885...          0.715076
# 43  [-0.0749434, 0.0049636485, -0.38076004, -0.087...          0.730514
# 46  [-0.23902147, 0.1319948, -0.29529908, -0.08826...          0.712706
# 48  [-0.19709682, -0.27392277, -0.5515117, -0.1885...          0.715076
# 53  [-0.23902147, 0.1319948, -0.29529908, -0.08826...          0.713914
# 54  [-0.23902147, 0.1319948, -0.29529908, -0.08826...          0.742774
# 57  [-0.23902147, 0.1319948, -0.29529908, -0.08826...          0.713914
# 60  [-0.23902147, 0.1319948, -0.29529908, -0.08826...          0.742774
# 63  [-0.0749434, 0.0049636485, -0.38076004, -0.087...          0.730514
# 64  [0.3134871, 0.057133112, -0.47340408, 0.099212...          0.701750
# 73  [-0.19709682, -0.27392277, -0.5515117, -0.1885...          0.715076
# 79  [-0.23902147, 0.1319948, -0.29529908, -0.08826...          0.712706
# 86  [-0.23902147, 0.1319948, -0.29529908, -0.08826...          0.712706
# 95  [-0.23902147, 0.1319948, -0.29529908, -0.08826...          0.713914

# %%
outliers.shape
# Out:
# (24, 8)
